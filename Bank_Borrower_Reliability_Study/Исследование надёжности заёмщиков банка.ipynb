# %% [markdown]
# # Исследование надёжности заёмщиков
#
# Заказчик — кредитный отдел банка. Нужно разобраться, влияет ли семейное положение и количество детей клиента на факт погашения кредита в срок. Входные данные от банка — статистика о платёжеспособности клиентов.
#
# Результаты исследования будут учтены при построении модели **кредитного скоринга** — специальной системы, которая оценивает способность потенциального заёмщика вернуть кредит банку.

# %% [markdown]
# ## Шаг 1. Откроем файл с данными и изучим общую информацию

# %%
import pandas as pd #импортируем билбиотеку Pandas

# %%
df = pd.read_csv('/data/data.csv') #Читаем dataset и сохраняем его в переменной df

# %%
df.head(30) #выводим первые 10 строк таблицы c данными
# Out:
#     children  days_employed  dob_years            education  education_id  \
# 0          1   -8437.673028         42               высшее             0
# 1          1   -4024.803754         36              среднее             1
# 2          0   -5623.422610         33              Среднее             1
# 3          3   -4124.747207         32              среднее             1
# 4          0  340266.072047         53              среднее             1
# 5          0    -926.185831         27               высшее             0
# 6          0   -2879.202052         43               высшее             0
# 7          0    -152.779569         50              СРЕДНЕЕ             1
# 8          2   -6929.865299         35               ВЫСШЕЕ             0
# 9          0   -2188.756445         41              среднее             1
# 10         2   -4171.483647         36               высшее             0
# 11         0    -792.701887         40              среднее             1
# 12         0            NaN         65              среднее             1
# 13         0   -1846.641941         54  неоконченное высшее             2
# 14         0   -1844.956182         56               высшее             0
# 15         1    -972.364419         26              среднее             1
# 16         0   -1719.934226         35              среднее             1
# 17         0   -2369.999720         33               высшее             0
# 18         0  400281.136913         53              среднее             1
# 19         0  -10038.818549         48              СРЕДНЕЕ             1
# 20         1   -1311.604166         36              среднее             1
# 21         1    -253.685166         33              среднее             1
# 22         1   -1766.644138         24              среднее             1
# 23         0    -272.981385         21               высшее             0
# 24         1  338551.952911         57              среднее             1
# 25         0  363548.489348         67              среднее             1
# 26         0            NaN         41              среднее             1
# 27         0    -529.191635         28               высшее             0
# 28         1    -717.274324         26               высшее             0
# 29         0            NaN         63              среднее             1
#
#             family_status  family_status_id gender  income_type  debt  \
# 0         женат / замужем                 0      F    сотрудник     0
# 1         женат / замужем                 0      F    сотрудник     0
# 2         женат / замужем                 0      M    сотрудник     0
# 3         женат / замужем                 0      M    сотрудник     0
# 4        гражданский брак                 1      F    пенсионер     0
# 5        гражданский брак                 1      M    компаньон     0
# 6         женат / замужем                 0      F    компаньон     0
# 7         женат / замужем                 0      M    сотрудник     0
# 8        гражданский брак                 1      F    сотрудник     0
# 9         женат / замужем                 0      M    сотрудник     0
# 10        женат / замужем                 0      M    компаньон     0
# 11        женат / замужем                 0      F    сотрудник     0
# 12       гражданский брак                 1      M    пенсионер     0
# 13        женат / замужем                 0      F    сотрудник     0
# 14       гражданский брак                 1      F    компаньон     1
# 15        женат / замужем                 0      F    сотрудник     0
# 16        женат / замужем                 0      F    сотрудник     0
# 17       гражданский брак                 1      M    сотрудник     0
# 18         вдовец / вдова                 2      F    пенсионер     0
# 19              в разводе                 3      F    сотрудник     0
# 20        женат / замужем                 0      M    сотрудник     0
# 21       гражданский брак                 1      F    сотрудник     0
# 22       гражданский брак                 1      F    сотрудник     0
# 23       гражданский брак                 1      M    сотрудник     0
# 24  Не женат / не замужем                 4      F    пенсионер     0
# 25        женат / замужем                 0      M    пенсионер     0
# 26        женат / замужем                 0      M  госслужащий     0
# 27        женат / замужем                 0      M    сотрудник     0
# 28        женат / замужем                 0      F    сотрудник     0
# 29  Не женат / не замужем                 4      F    пенсионер     0
#
#      total_income                                 purpose
# 0   253875.639453                           покупка жилья
# 1   112080.014102                 приобретение автомобиля
# 2   145885.952297                           покупка жилья
# 3   267628.550329              дополнительное образование
# 4   158616.077870                         сыграть свадьбу
# 5   255763.565419                           покупка жилья
# 6   240525.971920                       операции с жильем
# 7   135823.934197                             образование
# 8    95856.832424                   на проведение свадьбы
# 9   144425.938277                 покупка жилья для семьи
# 10  113943.491460                    покупка недвижимости
# 11   77069.234271       покупка коммерческой недвижимости
# 12            NaN                         сыграть свадьбу
# 13  130458.228857                 приобретение автомобиля
# 14  165127.911772              покупка жилой недвижимости
# 15  116820.904450  строительство собственной недвижимости
# 16  289202.704229                            недвижимость
# 17   90410.586745              строительство недвижимости
# 18   56823.777243      на покупку подержанного автомобиля
# 19  242831.107982            на покупку своего автомобиля
# 20  209552.644578                            недвижимость
# 21  131812.203909                 приобретение автомобиля
# 22  149681.140731      на покупку подержанного автомобиля
# 23  128265.720871                         сыграть свадьбу
# 24  290547.235997   операции с коммерческой недвижимостью
# 25   55112.757732                    покупка недвижимости
# 26            NaN                             образование
# 27  308848.983691  строительство собственной недвижимости
# 28  187863.237306  строительство собственной недвижимости
# 29            NaN        строительство жилой недвижимости

# %%
df.info() #получаем общую информацию о таблице
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21525 entries, 0 to 21524
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   children          21525 non-null  int64
#  1   days_employed     19351 non-null  float64
#  2   dob_years         21525 non-null  int64
#  3   education         21525 non-null  object
#  4   education_id      21525 non-null  int64
#  5   family_status     21525 non-null  object
#  6   family_status_id  21525 non-null  int64
#  7   gender            21525 non-null  object
#  8   income_type       21525 non-null  object
#  9   debt              21525 non-null  int64
#  10  total_income      19351 non-null  float64
#  11  purpose           21525 non-null  object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 2.0+ MB

# %% [markdown]
# **Вывод**

# %% [markdown]
# **Выгрузив таблицу мы обнаружили 12 столбцов и 3 типа данных: `float64`, `int64`, `object`.**
#
# * `children` - количество детей в семье заёмщика;
# * `days_employed` - общий трудовой стаж в днях заёмщика;
# * `dob_years` - возраст заёмщика в годах;
# * `education` -  уровень образования заёмщика;
# * `education_id` - идентификатор уровня образования заёмщика;
# * `family_status` - семейное положение заёмщика;
# * `family_status_id` - идентификатор семейного положения заёмщика;
# * `gender` - пол заёмщика;
# * `income_type` -  тип занятости заёмщика;
# * `debt` - имел ли заёмщик задолженность по возврату кредитов;
# * `total_income` - ежемесячный доход заёмщика;
# * `purpose` - цель получения кредита;
#
#    **В столбце `days_employed` нашли отрицательные значения.
#    В столбце `education` строчные буквы встречаются с прописными.
#    Так же обнаружены пропуски в столбцах: `days_employed`, `total_income`.**
#
#    **Для дальнейшего продвижения нужно устранить проблемы в данных.**

# %% [markdown]
# ## Шаг 2. Предобработка данных

# %% [markdown]
# ### Обработка пропусков

# %%
df.isna().sum() #находим пропущенные значения(где и сколько)
# Out:
# children               0
# days_employed       2174
# dob_years              0
# education              0
# education_id           0
# family_status          0
# family_status_id       0
# gender                 0
# income_type            0
# debt                   0
# total_income        2174
# purpose                0
# dtype: int64

# %% [markdown]
# **Обнаружены пропуски в столбцах: `days_employed`, `total_income`.
# Но сначала мы изменим отрицательные значения на положительные, далее займемся заменой пропусков.**

# %% [markdown]
# **Пишем функцию для устранения отрицательных значений.**

# %%
def removing_the_minus(i): #В столбце `days_employed` изменим отрицательные значение на положительные. Создадим функцию removing_the minus.
    if i < 1:
        i = i * (-1)
        return i
    return i

# %% [markdown]
# **Применим функцию `removing_the_minus` к столбцу `days_employed`**

# %%
df['days_employed'] = df['days_employed'].apply(removing_the_minus)

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# Хороший способ изменить отрицательные значения на положительные.
#
# Мы также можем использовать готовый метод `abs`, оставил пример ниже.
# </div>

# %%
df['days_employed'].abs()
# Out:
# 0          8437.673028
# 1          4024.803754
# 2          5623.422610
# 3          4124.747207
# 4        340266.072047
#              ...
# 21520      4529.316663
# 21521    343937.404131
# 21522      2113.346888
# 21523      3112.481705
# 21524      1984.507589
# Name: days_employed, Length: 21525, dtype: float64

# %% [markdown]
# **Заменяем пропуски медианой (среднее).**

# %%
df.loc[df['days_employed'].isna(), 'days_employed'] = df['days_employed'].median() #Медиана для столбца `days_employed` (делаем через `loc` по совету в методичке)
df.loc[df['total_income'].isna(), 'total_income'] = df['total_income'].median() #Медиана для столбца `total_income` (делаем через `loc` по совету в методичке)

# %%
df.isna().sum() # проверяем таблицу на отсутствие пропусков(пропусков нет)
# Out:
# children            0
# days_employed       0
# dob_years           0
# education           0
# education_id        0
# family_status       0
# family_status_id    0
# gender              0
# income_type         0
# debt                0
# total_income        0
# purpose             0
# dtype: int64

# %% [markdown]
# **Пропуски устранены.**

# %%
df.head(30) #проверяем таблицу на исправления отрицательных значений(значения исправлены)
# Out:
#     children  days_employed  dob_years            education  education_id  \
# 0          1    8437.673028         42               высшее             0
# 1          1    4024.803754         36              среднее             1
# 2          0    5623.422610         33              Среднее             1
# 3          3    4124.747207         32              среднее             1
# 4          0  340266.072047         53              среднее             1
# 5          0     926.185831         27               высшее             0
# 6          0    2879.202052         43               высшее             0
# 7          0     152.779569         50              СРЕДНЕЕ             1
# 8          2    6929.865299         35               ВЫСШЕЕ             0
# 9          0    2188.756445         41              среднее             1
# 10         2    4171.483647         36               высшее             0
# 11         0     792.701887         40              среднее             1
# 12         0    2194.220567         65              среднее             1
# 13         0    1846.641941         54  неоконченное высшее             2
# 14         0    1844.956182         56               высшее             0
# 15         1     972.364419         26              среднее             1
# 16         0    1719.934226         35              среднее             1
# 17         0    2369.999720         33               высшее             0
# 18         0  400281.136913         53              среднее             1
# 19         0   10038.818549         48              СРЕДНЕЕ             1
# 20         1    1311.604166         36              среднее             1
# 21         1     253.685166         33              среднее             1
# 22         1    1766.644138         24              среднее             1
# 23         0     272.981385         21               высшее             0
# 24         1  338551.952911         57              среднее             1
# 25         0  363548.489348         67              среднее             1
# 26         0    2194.220567         41              среднее             1
# 27         0     529.191635         28               высшее             0
# 28         1     717.274324         26               высшее             0
# 29         0    2194.220567         63              среднее             1
#
#             family_status  family_status_id gender  income_type  debt  \
# 0         женат / замужем                 0      F    сотрудник     0
# 1         женат / замужем                 0      F    сотрудник     0
# 2         женат / замужем                 0      M    сотрудник     0
# 3         женат / замужем                 0      M    сотрудник     0
# 4        гражданский брак                 1      F    пенсионер     0
# 5        гражданский брак                 1      M    компаньон     0
# 6         женат / замужем                 0      F    компаньон     0
# 7         женат / замужем                 0      M    сотрудник     0
# 8        гражданский брак                 1      F    сотрудник     0
# 9         женат / замужем                 0      M    сотрудник     0
# 10        женат / замужем                 0      M    компаньон     0
# 11        женат / замужем                 0      F    сотрудник     0
# 12       гражданский брак                 1      M    пенсионер     0
# 13        женат / замужем                 0      F    сотрудник     0
# 14       гражданский брак                 1      F    компаньон     1
# 15        женат / замужем                 0      F    сотрудник     0
# 16        женат / замужем                 0      F    сотрудник     0
# 17       гражданский брак                 1      M    сотрудник     0
# 18         вдовец / вдова                 2      F    пенсионер     0
# 19              в разводе                 3      F    сотрудник     0
# 20        женат / замужем                 0      M    сотрудник     0
# 21       гражданский брак                 1      F    сотрудник     0
# 22       гражданский брак                 1      F    сотрудник     0
# 23       гражданский брак                 1      M    сотрудник     0
# 24  Не женат / не замужем                 4      F    пенсионер     0
# 25        женат / замужем                 0      M    пенсионер     0
# 26        женат / замужем                 0      M  госслужащий     0
# 27        женат / замужем                 0      M    сотрудник     0
# 28        женат / замужем                 0      F    сотрудник     0
# 29  Не женат / не замужем                 4      F    пенсионер     0
#
#      total_income                                 purpose
# 0   253875.639453                           покупка жилья
# 1   112080.014102                 приобретение автомобиля
# 2   145885.952297                           покупка жилья
# 3   267628.550329              дополнительное образование
# 4   158616.077870                         сыграть свадьбу
# 5   255763.565419                           покупка жилья
# 6   240525.971920                       операции с жильем
# 7   135823.934197                             образование
# 8    95856.832424                   на проведение свадьбы
# 9   144425.938277                 покупка жилья для семьи
# 10  113943.491460                    покупка недвижимости
# 11   77069.234271       покупка коммерческой недвижимости
# 12  145017.937533                         сыграть свадьбу
# 13  130458.228857                 приобретение автомобиля
# 14  165127.911772              покупка жилой недвижимости
# 15  116820.904450  строительство собственной недвижимости
# 16  289202.704229                            недвижимость
# 17   90410.586745              строительство недвижимости
# 18   56823.777243      на покупку подержанного автомобиля
# 19  242831.107982            на покупку своего автомобиля
# 20  209552.644578                            недвижимость
# 21  131812.203909                 приобретение автомобиля
# 22  149681.140731      на покупку подержанного автомобиля
# 23  128265.720871                         сыграть свадьбу
# 24  290547.235997   операции с коммерческой недвижимостью
# 25   55112.757732                    покупка недвижимости
# 26  145017.937533                             образование
# 27  308848.983691  строительство собственной недвижимости
# 28  187863.237306  строительство собственной недвижимости
# 29  145017.937533        строительство жилой недвижимости

# %% [markdown]
# **Есть аномально большие значения в столбце `days_employed`, с такими значенями работать не удобно. Есть предположение, что это дни. Переводим их в года.**

# %%
def transform_in_years(i): #Пишем функцию для перевода дней в столбце `days_employed` в года
    i = i/365
    return i

# %%
df['days_employed'] = df['days_employed'].apply(transform_in_years) #применяем функцию

# %%
df.head(30) # Проверяем результат
# Out:
#     children  days_employed  dob_years            education  education_id  \
# 0          1      23.116912         42               высшее             0
# 1          1      11.026860         36              среднее             1
# 2          0      15.406637         33              Среднее             1
# 3          3      11.300677         32              среднее             1
# 4          0     932.235814         53              среднее             1
# 5          0       2.537495         27               высшее             0
# 6          0       7.888225         43               высшее             0
# 7          0       0.418574         50              СРЕДНЕЕ             1
# 8          2      18.985932         35               ВЫСШЕЕ             0
# 9          0       5.996593         41              среднее             1
# 10         2      11.428722         36               высшее             0
# 11         0       2.171786         40              среднее             1
# 12         0       6.011563         65              среднее             1
# 13         0       5.059293         54  неоконченное высшее             2
# 14         0       5.054674         56               высшее             0
# 15         1       2.664012         26              среднее             1
# 16         0       4.712149         35              среднее             1
# 17         0       6.493150         33               высшее             0
# 18         0    1096.660649         53              среднее             1
# 19         0      27.503612         48              СРЕДНЕЕ             1
# 20         1       3.593436         36              среднее             1
# 21         1       0.695028         33              среднее             1
# 22         1       4.840121         24              среднее             1
# 23         0       0.747894         21               высшее             0
# 24         1     927.539597         57              среднее             1
# 25         0     996.023258         67              среднее             1
# 26         0       6.011563         41              среднее             1
# 27         0       1.449840         28               высшее             0
# 28         1       1.965135         26               высшее             0
# 29         0       6.011563         63              среднее             1
#
#             family_status  family_status_id gender  income_type  debt  \
# 0         женат / замужем                 0      F    сотрудник     0
# 1         женат / замужем                 0      F    сотрудник     0
# 2         женат / замужем                 0      M    сотрудник     0
# 3         женат / замужем                 0      M    сотрудник     0
# 4        гражданский брак                 1      F    пенсионер     0
# 5        гражданский брак                 1      M    компаньон     0
# 6         женат / замужем                 0      F    компаньон     0
# 7         женат / замужем                 0      M    сотрудник     0
# 8        гражданский брак                 1      F    сотрудник     0
# 9         женат / замужем                 0      M    сотрудник     0
# 10        женат / замужем                 0      M    компаньон     0
# 11        женат / замужем                 0      F    сотрудник     0
# 12       гражданский брак                 1      M    пенсионер     0
# 13        женат / замужем                 0      F    сотрудник     0
# 14       гражданский брак                 1      F    компаньон     1
# 15        женат / замужем                 0      F    сотрудник     0
# 16        женат / замужем                 0      F    сотрудник     0
# 17       гражданский брак                 1      M    сотрудник     0
# 18         вдовец / вдова                 2      F    пенсионер     0
# 19              в разводе                 3      F    сотрудник     0
# 20        женат / замужем                 0      M    сотрудник     0
# 21       гражданский брак                 1      F    сотрудник     0
# 22       гражданский брак                 1      F    сотрудник     0
# 23       гражданский брак                 1      M    сотрудник     0
# 24  Не женат / не замужем                 4      F    пенсионер     0
# 25        женат / замужем                 0      M    пенсионер     0
# 26        женат / замужем                 0      M  госслужащий     0
# 27        женат / замужем                 0      M    сотрудник     0
# 28        женат / замужем                 0      F    сотрудник     0
# 29  Не женат / не замужем                 4      F    пенсионер     0
#
#      total_income                                 purpose
# 0   253875.639453                           покупка жилья
# 1   112080.014102                 приобретение автомобиля
# 2   145885.952297                           покупка жилья
# 3   267628.550329              дополнительное образование
# 4   158616.077870                         сыграть свадьбу
# 5   255763.565419                           покупка жилья
# 6   240525.971920                       операции с жильем
# 7   135823.934197                             образование
# 8    95856.832424                   на проведение свадьбы
# 9   144425.938277                 покупка жилья для семьи
# 10  113943.491460                    покупка недвижимости
# 11   77069.234271       покупка коммерческой недвижимости
# 12  145017.937533                         сыграть свадьбу
# 13  130458.228857                 приобретение автомобиля
# 14  165127.911772              покупка жилой недвижимости
# 15  116820.904450  строительство собственной недвижимости
# 16  289202.704229                            недвижимость
# 17   90410.586745              строительство недвижимости
# 18   56823.777243      на покупку подержанного автомобиля
# 19  242831.107982            на покупку своего автомобиля
# 20  209552.644578                            недвижимость
# 21  131812.203909                 приобретение автомобиля
# 22  149681.140731      на покупку подержанного автомобиля
# 23  128265.720871                         сыграть свадьбу
# 24  290547.235997   операции с коммерческой недвижимостью
# 25   55112.757732                    покупка недвижимости
# 26  145017.937533                             образование
# 27  308848.983691  строительство собственной недвижимости
# 28  187863.237306  строительство собственной недвижимости
# 29  145017.937533        строительство жилой недвижимости

# %% [markdown]
# **Некоторые значения так и остались аномально большими. Появилось предположение, что эти данные могли быть взяты из другой системы. Пишем еще одну функцию.**

# %%
def into_years(i):
    if i > 100:
        i = i / 24
    return i

# %%
df['days_employed'] = df['days_employed'].apply(into_years) #применяем функцию

# %%
df.head(30) #проверяем результат
# Out:
#     children  days_employed  dob_years            education  education_id  \
# 0          1      23.116912         42               высшее             0
# 1          1      11.026860         36              среднее             1
# 2          0      15.406637         33              Среднее             1
# 3          3      11.300677         32              среднее             1
# 4          0      38.843159         53              среднее             1
# 5          0       2.537495         27               высшее             0
# 6          0       7.888225         43               высшее             0
# 7          0       0.418574         50              СРЕДНЕЕ             1
# 8          2      18.985932         35               ВЫСШЕЕ             0
# 9          0       5.996593         41              среднее             1
# 10         2      11.428722         36               высшее             0
# 11         0       2.171786         40              среднее             1
# 12         0       6.011563         65              среднее             1
# 13         0       5.059293         54  неоконченное высшее             2
# 14         0       5.054674         56               высшее             0
# 15         1       2.664012         26              среднее             1
# 16         0       4.712149         35              среднее             1
# 17         0       6.493150         33               высшее             0
# 18         0      45.694194         53              среднее             1
# 19         0      27.503612         48              СРЕДНЕЕ             1
# 20         1       3.593436         36              среднее             1
# 21         1       0.695028         33              среднее             1
# 22         1       4.840121         24              среднее             1
# 23         0       0.747894         21               высшее             0
# 24         1      38.647483         57              среднее             1
# 25         0      41.500969         67              среднее             1
# 26         0       6.011563         41              среднее             1
# 27         0       1.449840         28               высшее             0
# 28         1       1.965135         26               высшее             0
# 29         0       6.011563         63              среднее             1
#
#             family_status  family_status_id gender  income_type  debt  \
# 0         женат / замужем                 0      F    сотрудник     0
# 1         женат / замужем                 0      F    сотрудник     0
# 2         женат / замужем                 0      M    сотрудник     0
# 3         женат / замужем                 0      M    сотрудник     0
# 4        гражданский брак                 1      F    пенсионер     0
# 5        гражданский брак                 1      M    компаньон     0
# 6         женат / замужем                 0      F    компаньон     0
# 7         женат / замужем                 0      M    сотрудник     0
# 8        гражданский брак                 1      F    сотрудник     0
# 9         женат / замужем                 0      M    сотрудник     0
# 10        женат / замужем                 0      M    компаньон     0
# 11        женат / замужем                 0      F    сотрудник     0
# 12       гражданский брак                 1      M    пенсионер     0
# 13        женат / замужем                 0      F    сотрудник     0
# 14       гражданский брак                 1      F    компаньон     1
# 15        женат / замужем                 0      F    сотрудник     0
# 16        женат / замужем                 0      F    сотрудник     0
# 17       гражданский брак                 1      M    сотрудник     0
# 18         вдовец / вдова                 2      F    пенсионер     0
# 19              в разводе                 3      F    сотрудник     0
# 20        женат / замужем                 0      M    сотрудник     0
# 21       гражданский брак                 1      F    сотрудник     0
# 22       гражданский брак                 1      F    сотрудник     0
# 23       гражданский брак                 1      M    сотрудник     0
# 24  Не женат / не замужем                 4      F    пенсионер     0
# 25        женат / замужем                 0      M    пенсионер     0
# 26        женат / замужем                 0      M  госслужащий     0
# 27        женат / замужем                 0      M    сотрудник     0
# 28        женат / замужем                 0      F    сотрудник     0
# 29  Не женат / не замужем                 4      F    пенсионер     0
#
#      total_income                                 purpose
# 0   253875.639453                           покупка жилья
# 1   112080.014102                 приобретение автомобиля
# 2   145885.952297                           покупка жилья
# 3   267628.550329              дополнительное образование
# 4   158616.077870                         сыграть свадьбу
# 5   255763.565419                           покупка жилья
# 6   240525.971920                       операции с жильем
# 7   135823.934197                             образование
# 8    95856.832424                   на проведение свадьбы
# 9   144425.938277                 покупка жилья для семьи
# 10  113943.491460                    покупка недвижимости
# 11   77069.234271       покупка коммерческой недвижимости
# 12  145017.937533                         сыграть свадьбу
# 13  130458.228857                 приобретение автомобиля
# 14  165127.911772              покупка жилой недвижимости
# 15  116820.904450  строительство собственной недвижимости
# 16  289202.704229                            недвижимость
# 17   90410.586745              строительство недвижимости
# 18   56823.777243      на покупку подержанного автомобиля
# 19  242831.107982            на покупку своего автомобиля
# 20  209552.644578                            недвижимость
# 21  131812.203909                 приобретение автомобиля
# 22  149681.140731      на покупку подержанного автомобиля
# 23  128265.720871                         сыграть свадьбу
# 24  290547.235997   операции с коммерческой недвижимостью
# 25   55112.757732                    покупка недвижимости
# 26  145017.937533                             образование
# 27  308848.983691  строительство собственной недвижимости
# 28  187863.237306  строительство собственной недвижимости
# 29  145017.937533        строительство жилой недвижимости

# %% [markdown]
# **Вывод**

# %% [markdown]
# * в столбце `days_employed` все отрицательные значения заменены на положительные, заменены все пропуски медианой данного столбца. А так же исправлен стаж работы (ранее исчислялся для некоторых заёмщиков в днях или часах) на года.
# * в столбце `total_income` мы так же заменили все пропуски.**
#
# * 2174 заёмщика не указали свой стаж работы и уровень дохода. Вероятнее всего, они умышленно не заполняли эти данные (работа с серой зарплатой)**

# %% [markdown]
# ### Замена типа данных

# %%
df.info() #проверяем какие типы данных присутствуют в таблице
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21525 entries, 0 to 21524
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   children          21525 non-null  int64
#  1   days_employed     21525 non-null  float64
#  2   dob_years         21525 non-null  int64
#  3   education         21525 non-null  object
#  4   education_id      21525 non-null  int64
#  5   family_status     21525 non-null  object
#  6   family_status_id  21525 non-null  int64
#  7   gender            21525 non-null  object
#  8   income_type       21525 non-null  object
#  9   debt              21525 non-null  int64
#  10  total_income      21525 non-null  float64
#  11  purpose           21525 non-null  object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 2.0+ MB

# %% [markdown]
# **Все столбцы имеют корректный тип данных. Но столбцы `days_employed` (отработанные дни) и `total_income`(общий доход) указаны с дробной частью (`float`).Переведем их в `int`.**

# %%
df[['days_employed', 'total_income']] = df[['days_employed', 'total_income']].astype(int) #применяем метод astype() для изменения типа float на int.

# %%
df.info() #проверяем
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21525 entries, 0 to 21524
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   children          21525 non-null  int64
#  1   days_employed     21525 non-null  int32
#  2   dob_years         21525 non-null  int64
#  3   education         21525 non-null  object
#  4   education_id      21525 non-null  int64
#  5   family_status     21525 non-null  object
#  6   family_status_id  21525 non-null  int64
#  7   gender            21525 non-null  object
#  8   income_type       21525 non-null  object
#  9   debt              21525 non-null  int64
#  10  total_income      21525 non-null  int32
#  11  purpose           21525 non-null  object
# dtypes: int32(2), int64(5), object(5)
# memory usage: 1.8+ MB

# %% [markdown]
# **Тип данных изменился**

# %%
df.head(30) # столбцы `days_employed` и `total_income` приведены к целочисленному типу int.
# Out:
#     children  days_employed  dob_years            education  education_id  \
# 0          1             23         42               высшее             0
# 1          1             11         36              среднее             1
# 2          0             15         33              Среднее             1
# 3          3             11         32              среднее             1
# 4          0             38         53              среднее             1
# 5          0              2         27               высшее             0
# 6          0              7         43               высшее             0
# 7          0              0         50              СРЕДНЕЕ             1
# 8          2             18         35               ВЫСШЕЕ             0
# 9          0              5         41              среднее             1
# 10         2             11         36               высшее             0
# 11         0              2         40              среднее             1
# 12         0              6         65              среднее             1
# 13         0              5         54  неоконченное высшее             2
# 14         0              5         56               высшее             0
# 15         1              2         26              среднее             1
# 16         0              4         35              среднее             1
# 17         0              6         33               высшее             0
# 18         0             45         53              среднее             1
# 19         0             27         48              СРЕДНЕЕ             1
# 20         1              3         36              среднее             1
# 21         1              0         33              среднее             1
# 22         1              4         24              среднее             1
# 23         0              0         21               высшее             0
# 24         1             38         57              среднее             1
# 25         0             41         67              среднее             1
# 26         0              6         41              среднее             1
# 27         0              1         28               высшее             0
# 28         1              1         26               высшее             0
# 29         0              6         63              среднее             1
#
#             family_status  family_status_id gender  income_type  debt  \
# 0         женат / замужем                 0      F    сотрудник     0
# 1         женат / замужем                 0      F    сотрудник     0
# 2         женат / замужем                 0      M    сотрудник     0
# 3         женат / замужем                 0      M    сотрудник     0
# 4        гражданский брак                 1      F    пенсионер     0
# 5        гражданский брак                 1      M    компаньон     0
# 6         женат / замужем                 0      F    компаньон     0
# 7         женат / замужем                 0      M    сотрудник     0
# 8        гражданский брак                 1      F    сотрудник     0
# 9         женат / замужем                 0      M    сотрудник     0
# 10        женат / замужем                 0      M    компаньон     0
# 11        женат / замужем                 0      F    сотрудник     0
# 12       гражданский брак                 1      M    пенсионер     0
# 13        женат / замужем                 0      F    сотрудник     0
# 14       гражданский брак                 1      F    компаньон     1
# 15        женат / замужем                 0      F    сотрудник     0
# 16        женат / замужем                 0      F    сотрудник     0
# 17       гражданский брак                 1      M    сотрудник     0
# 18         вдовец / вдова                 2      F    пенсионер     0
# 19              в разводе                 3      F    сотрудник     0
# 20        женат / замужем                 0      M    сотрудник     0
# 21       гражданский брак                 1      F    сотрудник     0
# 22       гражданский брак                 1      F    сотрудник     0
# 23       гражданский брак                 1      M    сотрудник     0
# 24  Не женат / не замужем                 4      F    пенсионер     0
# 25        женат / замужем                 0      M    пенсионер     0
# 26        женат / замужем                 0      M  госслужащий     0
# 27        женат / замужем                 0      M    сотрудник     0
# 28        женат / замужем                 0      F    сотрудник     0
# 29  Не женат / не замужем                 4      F    пенсионер     0
#
#     total_income                                 purpose
# 0         253875                           покупка жилья
# 1         112080                 приобретение автомобиля
# 2         145885                           покупка жилья
# 3         267628              дополнительное образование
# 4         158616                         сыграть свадьбу
# 5         255763                           покупка жилья
# 6         240525                       операции с жильем
# 7         135823                             образование
# 8          95856                   на проведение свадьбы
# 9         144425                 покупка жилья для семьи
# 10        113943                    покупка недвижимости
# 11         77069       покупка коммерческой недвижимости
# 12        145017                         сыграть свадьбу
# 13        130458                 приобретение автомобиля
# 14        165127              покупка жилой недвижимости
# 15        116820  строительство собственной недвижимости
# 16        289202                            недвижимость
# 17         90410              строительство недвижимости
# 18         56823      на покупку подержанного автомобиля
# 19        242831            на покупку своего автомобиля
# 20        209552                            недвижимость
# 21        131812                 приобретение автомобиля
# 22        149681      на покупку подержанного автомобиля
# 23        128265                         сыграть свадьбу
# 24        290547   операции с коммерческой недвижимостью
# 25         55112                    покупка недвижимости
# 26        145017                             образование
# 27        308848  строительство собственной недвижимости
# 28        187863  строительство собственной недвижимости
# 29        145017        строительство жилой недвижимости

# %% [markdown]
# **Вывод**

# %% [markdown]
# * в столбцах `days_employed`(общий трудовой стаж в днях заёмщика) и `total_income`(ежемесячный доход заёмщика) мы наблюдаем тип `float`.**
#
# * для удобства чтения и дальнейших манипуляций с этими данными нам надо привести тип данных этих столбцов к целочисленным(`int`).**
#
# * так как никто не говорит, что стаж равен 45.694194, а доход равен 267628.550329.**
#
# * был выбран метод astype(), так как этот метод подходит для перевода в целые числа.**

# %% [markdown]
# ### Обработка дубликатов

# %% [markdown]
# **Выводим на экран подсчет уникальных значений столбцов: `education`, `family_status`, `gender`, `income_type`, `purpose`, `children` методом value_counts()**

# %%
display(df['education'].value_counts())
# Out:
# среднее                13750
# высшее                  4718
# СРЕДНЕЕ                  772
# Среднее                  711
# неоконченное высшее      668
# ВЫСШЕЕ                   274
# Высшее                   268
# начальное                250
# Неоконченное высшее       47
# НЕОКОНЧЕННОЕ ВЫСШЕЕ       29
# НАЧАЛЬНОЕ                 17
# Начальное                 15
# ученая степень             4
# УЧЕНАЯ СТЕПЕНЬ             1
# Ученая степень             1
# Name: education, dtype: int64

# %%
display(df['family_status'].value_counts())
# Out:
# женат / замужем          12380
# гражданский брак          4177
# Не женат / не замужем     2813
# в разводе                 1195
# вдовец / вдова             960
# Name: family_status, dtype: int64

# %%
display(df['gender'].value_counts())
# Out:
# F      14236
# M       7288
# XNA        1
# Name: gender, dtype: int64

# %%
display(df['income_type'].value_counts())
# Out:
# сотрудник          11119
# компаньон           5085
# пенсионер           3856
# госслужащий         1459
# безработный            2
# предприниматель        2
# в декрете              1
# студент                1
# Name: income_type, dtype: int64

# %%
display(df['purpose'].value_counts())
# Out:
# свадьба                                   797
# на проведение свадьбы                     777
# сыграть свадьбу                           774
# операции с недвижимостью                  676
# покупка коммерческой недвижимости         664
# покупка жилья для сдачи                   653
# операции с жильем                         653
# операции с коммерческой недвижимостью     651
# покупка жилья                             647
# жилье                                     647
# покупка жилья для семьи                   641
# строительство собственной недвижимости    635
# недвижимость                              634
# операции со своей недвижимостью           630
# строительство жилой недвижимости          626
# покупка недвижимости                      624
# покупка своего жилья                      620
# строительство недвижимости                620
# ремонт жилью                              612
# покупка жилой недвижимости                607
# на покупку своего автомобиля              505
# заняться высшим образованием              496
# автомобиль                                495
# сделка с подержанным автомобилем          489
# свой автомобиль                           480
# на покупку подержанного автомобиля        479
# автомобили                                478
# на покупку автомобиля                     472
# приобретение автомобиля                   462
# дополнительное образование                462
# сделка с автомобилем                      455
# высшее образование                        453
# образование                               447
# получение дополнительного образования     447
# получение образования                     443
# профильное образование                    436
# получение высшего образования             426
# заняться образованием                     412
# Name: purpose, dtype: int64

# %%
display(df['children'].value_counts())
# Out:
#  0     14149
#  1      4818
#  2      2055
#  3       330
#  20       76
# -1        47
#  4        41
#  5         9
# Name: children, dtype: int64

# %% [markdown]
# **Приводим значения столбцов `education`, `family_status` к строчному типу методом `str.lower()`**

# %%
df['education'] = df['education'].str.lower()

# %%
df['family_status'] = df['family_status'].str.lower()

# %% [markdown]
# **В столбце `children` исправляем аномальные значения методом `replace`**

# %%
df['children'] = df['children'].replace(-1, 1)

# %%
df['children'] = df['children'].replace(20, 2)

# %%
display(df['education'].value_counts()) #проверяем
# Out:
# среднее                15233
# высшее                  5260
# неоконченное высшее      744
# начальное                282
# ученая степень             6
# Name: education, dtype: int64

# %%
display(df['family_status'].value_counts()) # проверяем
# Out:
# женат / замужем          12380
# гражданский брак          4177
# не женат / не замужем     2813
# в разводе                 1195
# вдовец / вдова             960
# Name: family_status, dtype: int64

# %% [markdown]
# **Значения приведены к строчному типу**

# %%
display(df['children'].value_counts())
# Out:
# 0    14149
# 1     4865
# 2     2131
# 3      330
# 4       41
# 5        9
# Name: children, dtype: int64

# %% [markdown]
# **Аномальные значения исправлены**

# %%
df.duplicated().sum() #считаем дубликаты методом sum()
# Out:
# 71

# %% [markdown]
# Далее удаляем дубликаты из датафрейма методом `drop_duplicates()`

# %%
df = df.drop_duplicates().reset_index(drop=True)

# %%
df.duplicated().sum() #проверяем
# Out:
# 0

# %% [markdown]
# **Вывод**

# %% [markdown]
# * Дубликаты удалены
# * Аномальные значения справлены на корректные
# * В столбцах `education` и `family_status` значения приведены к строчному типу

# %% [markdown]
# ### Лемматизация

# %% [markdown]
# **Проанализируем нашу таблицу. Следующим шагом будет лемматизация столбца `purpose`. В остальных она не требуется.**

# %% [markdown]
# **Импортируем библиотеку `pymystem3` для дальнейшей работы с лемматизацей.**

# %%
from pymystem3 import Mystem # импортируем библиотеку с функцией лемматизации на русском языке
m = Mystem() # присвоим переменную m

# %% [markdown]
# **Найдем уникальные значения столбца `purpose`**

# %%
text = df['purpose'].unique()
text
# Out:
# array(['покупка жилья', 'приобретение автомобиля',
#        'дополнительное образование', 'сыграть свадьбу',
#        'операции с жильем', 'образование', 'на проведение свадьбы',
#        'покупка жилья для семьи', 'покупка недвижимости',
#        'покупка коммерческой недвижимости', 'покупка жилой недвижимости',
#        'строительство собственной недвижимости', 'недвижимость',
#        'строительство недвижимости', 'на покупку подержанного автомобиля',
#        'на покупку своего автомобиля',
#        'операции с коммерческой недвижимостью',
#        'строительство жилой недвижимости', 'жилье',
#        'операции со своей недвижимостью', 'автомобили',
#        'заняться образованием', 'сделка с подержанным автомобилем',
#        'получение образования', 'автомобиль', 'свадьба',
#        'получение дополнительного образования', 'покупка своего жилья',
#        'операции с недвижимостью', 'получение высшего образования',
#        'свой автомобиль', 'сделка с автомобилем',
#        'профильное образование', 'высшее образование',
#        'покупка жилья для сдачи', 'на покупку автомобиля', 'ремонт жилью',
#        'заняться высшим образованием'], dtype=object)

# %% [markdown]
# **Далее склеим в одну строчку, методом `join()`**

# %%
text_str = ','.join(text)
text_str
# Out:
# 'покупка жилья,приобретение автомобиля,дополнительное образование,сыграть свадьбу,операции с жильем,образование,на проведение свадьбы,покупка жилья для семьи,покупка недвижимости,покупка коммерческой недвижимости,покупка жилой недвижимости,строительство собственной недвижимости,недвижимость,строительство недвижимости,на покупку подержанного автомобиля,на покупку своего автомобиля,операции с коммерческой недвижимостью,строительство жилой недвижимости,жилье,операции со своей недвижимостью,автомобили,заняться образованием,сделка с подержанным автомобилем,получение образования,автомобиль,свадьба,получение дополнительного образования,покупка своего жилья,операции с недвижимостью,получение высшего образования,свой автомобиль,сделка с автомобилем,профильное образование,высшее образование,покупка жилья для сдачи,на покупку автомобиля,ремонт жилью,заняться высшим образованием'

# %% [markdown]
# **Производим лемматизацию строки `text_str`**

# %%
lemmas = m.lemmatize(text_str)
lemmas
# Out:
# ['покупка',
#  ' ',
#  'жилье',
#  ',',
#  'приобретение',
#  ' ',
#  'автомобиль',
#  ',',
#  'дополнительный',
#  ' ',
#  'образование',
#  ',',
#  'сыграть',
#  ' ',
#  'свадьба',
#  ',',
#  'операция',
#  ' ',
#  'с',
#  ' ',
#  'жилье',
#  ',',
#  'образование',
#  ',',
#  'на',
#  ' ',
#  'проведение',
#  ' ',
#  'свадьба',
#  ',',
#  'покупка',
#  ' ',
#  'жилье',
#  ' ',
#  'для',
#  ' ',
#  'семья',
#  ',',
#  'покупка',
#  ' ',
#  'недвижимость',
#  ',',
#  'покупка',
#  ' ',
#  'коммерческий',
#  ' ',
#  'недвижимость',
#  ',',
#  'покупка',
#  ' ',
#  'жилой',
#  ' ',
#  'недвижимость',
#  ',',
#  'строительство',
#  ' ',
#  'собственный',
#  ' ',
#  'недвижимость',
#  ',',
#  'недвижимость',
#  ',',
#  'строительство',
#  ' ',
#  'недвижимость',
#  ',',
#  'на',
#  ' ',
#  'покупка',
#  ' ',
#  'подержать',
#  ' ',
#  'автомобиль',
#  ',',
#  'на',
#  ' ',
#  'покупка',
#  ' ',
#  'свой',
#  ' ',
#  'автомобиль',
#  ',',
#  'операция',
#  ' ',
#  'с',
#  ' ',
#  'коммерческий',
#  ' ',
#  'недвижимость',
#  ',',
#  'строительство',
#  ' ',
#  'жилой',
#  ' ',
#  'недвижимость',
#  ',',
#  'жилье',
#  ',',
#  'операция',
#  ' ',
#  'со',
#  ' ',
#  'свой',
#  ' ',
#  'недвижимость',
#  ',',
#  'автомобиль',
#  ',',
#  'заниматься',
#  ' ',
#  'образование',
#  ',',
#  'сделка',
#  ' ',
#  'с',
#  ' ',
#  'подержать',
#  ' ',
#  'автомобиль',
#  ',',
#  'получение',
#  ' ',
#  'образование',
#  ',',
#  'автомобиль',
#  ',',
#  'свадьба',
#  ',',
#  'получение',
#  ' ',
#  'дополнительный',
#  ' ',
#  'образование',
#  ',',
#  'покупка',
#  ' ',
#  'свой',
#  ' ',
#  'жилье',
#  ',',
#  'операция',
#  ' ',
#  'с',
#  ' ',
#  'недвижимость',
#  ',',
#  'получение',
#  ' ',
#  'высокий',
#  ' ',
#  'образование',
#  ',',
#  'свой',
#  ' ',
#  'автомобиль',
#  ',',
#  'сделка',
#  ' ',
#  'с',
#  ' ',
#  'автомобиль',
#  ',',
#  'профильный',
#  ' ',
#  'образование',
#  ',',
#  'высокий',
#  ' ',
#  'образование',
#  ',',
#  'покупка',
#  ' ',
#  'жилье',
#  ' ',
#  'для',
#  ' ',
#  'сдача',
#  ',',
#  'на',
#  ' ',
#  'покупка',
#  ' ',
#  'автомобиль',
#  ',',
#  'ремонт',
#  ' ',
#  'жилье',
#  ',',
#  'заниматься',
#  ' ',
#  'высокий',
#  ' ',
#  'образование',
#  '\n']

# %% [markdown]
# **Далее с помощью `Counter` посчитаем переодичность появления слов. Для этого вызовем контейнер `Counter` из модуля ` collections`.**

# %%
from collections import Counter # Вызов Counter

# %%
Counter(lemmas) # Подсчет колличества каждого слова в lemmas
# Out:
# Counter({'покупка': 10,
#          ' ': 59,
#          'жилье': 7,
#          ',': 37,
#          'приобретение': 1,
#          'автомобиль': 9,
#          'дополнительный': 2,
#          'образование': 9,
#          'сыграть': 1,
#          'свадьба': 3,
#          'операция': 4,
#          'с': 5,
#          'на': 4,
#          'проведение': 1,
#          'для': 2,
#          'семья': 1,
#          'недвижимость': 10,
#          'коммерческий': 2,
#          'жилой': 2,
#          'строительство': 3,
#          'собственный': 1,
#          'подержать': 2,
#          'свой': 4,
#          'со': 1,
#          'заниматься': 2,
#          'сделка': 2,
#          'получение': 3,
#          'высокий': 3,
#          'профильный': 1,
#          'сдача': 1,
#          'ремонт': 1,
#          '\n': 1})

# %% [markdown]
# **После выделим вручную из этого списка часто повторяющиеся существительные - это будут основные категории**

# %% [markdown]
# **А именно: жилье, недвижимость, автомобиль, образование, операция, свадьба.**

# %% [markdown]
# **Напишем функцию для `apply`, которая лемматизирует последовательно каждую ячейку столбца `purpose` и проверит, какая из категорий обнаруживается в лематезированном варианте.**

# %%
def lemmatize(purpose):
    if 'жил' in purpose:
        return 'жилье'
    if 'недвиж' in purpose:
        return 'неджижимость'
    if 'авто' in purpose:
        return 'автомобиль'
    if 'образ' in purpose:
        return 'образование'
    if 'опер' in purpose:
        return 'операция'
    if 'свад' in purpose:
        return 'свдьба'

# %% [markdown]
# **К созданному новому столбцу с категориями `purpose_category` применим функцию `lemmatize`**

# %%
df['purpose_category'] = df['purpose'].apply(lemmatize)

# %%
df.head(50) # проверка
# Out:
#     children  days_employed  dob_years            education  education_id  \
# 0          1             23         42               высшее             0
# 1          1             11         36              среднее             1
# 2          0             15         33              среднее             1
# 3          3             11         32              среднее             1
# 4          0             38         53              среднее             1
# 5          0              2         27               высшее             0
# 6          0              7         43               высшее             0
# 7          0              0         50              среднее             1
# 8          2             18         35               высшее             0
# 9          0              5         41              среднее             1
# 10         2             11         36               высшее             0
# 11         0              2         40              среднее             1
# 12         0              6         65              среднее             1
# 13         0              5         54  неоконченное высшее             2
# 14         0              5         56               высшее             0
# 15         1              2         26              среднее             1
# 16         0              4         35              среднее             1
# 17         0              6         33               высшее             0
# 18         0             45         53              среднее             1
# 19         0             27         48              среднее             1
# 20         1              3         36              среднее             1
# 21         1              0         33              среднее             1
# 22         1              4         24              среднее             1
# 23         0              0         21               высшее             0
# 24         1             38         57              среднее             1
# 25         0             41         67              среднее             1
# 26         0              6         41              среднее             1
# 27         0              1         28               высшее             0
# 28         1              1         26               высшее             0
# 29         0              6         63              среднее             1
# 30         1             38         62              среднее             1
# 31         0              4         47            начальное             3
# 32         0             12         34              среднее             1
# 33         0              4         48              среднее             1
# 34         0             12         35              среднее             1
# 35         0             44         68              среднее             1
# 36         0              0         33              среднее             1
# 37         0             17         43               высшее             0
# 38         0              1         25               высшее             0
# 39         0              1         31               высшее             0
# 40         0              2         30              среднее             1
# 41         0              6         50              среднее             1
# 42         0              3         20  неоконченное высшее             2
# 43         0             11         43  неоконченное высшее             2
# 44         1              3         26              среднее             1
# 45         1              2         49              среднее             1
# 46         2              6         37              среднее             1
# 47         1              7         33               высшее             0
# 48         0              9         45              среднее             1
# 49         0              3         54              среднее             1
#
#             family_status  family_status_id gender  income_type  debt  \
# 0         женат / замужем                 0      F    сотрудник     0
# 1         женат / замужем                 0      F    сотрудник     0
# 2         женат / замужем                 0      M    сотрудник     0
# 3         женат / замужем                 0      M    сотрудник     0
# 4        гражданский брак                 1      F    пенсионер     0
# 5        гражданский брак                 1      M    компаньон     0
# 6         женат / замужем                 0      F    компаньон     0
# 7         женат / замужем                 0      M    сотрудник     0
# 8        гражданский брак                 1      F    сотрудник     0
# 9         женат / замужем                 0      M    сотрудник     0
# 10        женат / замужем                 0      M    компаньон     0
# 11        женат / замужем                 0      F    сотрудник     0
# 12       гражданский брак                 1      M    пенсионер     0
# 13        женат / замужем                 0      F    сотрудник     0
# 14       гражданский брак                 1      F    компаньон     1
# 15        женат / замужем                 0      F    сотрудник     0
# 16        женат / замужем                 0      F    сотрудник     0
# 17       гражданский брак                 1      M    сотрудник     0
# 18         вдовец / вдова                 2      F    пенсионер     0
# 19              в разводе                 3      F    сотрудник     0
# 20        женат / замужем                 0      M    сотрудник     0
# 21       гражданский брак                 1      F    сотрудник     0
# 22       гражданский брак                 1      F    сотрудник     0
# 23       гражданский брак                 1      M    сотрудник     0
# 24  не женат / не замужем                 4      F    пенсионер     0
# 25        женат / замужем                 0      M    пенсионер     0
# 26        женат / замужем                 0      M  госслужащий     0
# 27        женат / замужем                 0      M    сотрудник     0
# 28        женат / замужем                 0      F    сотрудник     0
# 29  не женат / не замужем                 4      F    пенсионер     0
# 30        женат / замужем                 0      F    пенсионер     0
# 31        женат / замужем                 0      F    сотрудник     0
# 32       гражданский брак                 1      F    сотрудник     1
# 33        женат / замужем                 0      F    компаньон     0
# 34        женат / замужем                 0      F    сотрудник     0
# 35       гражданский брак                 1      M    пенсионер     0
# 36  не женат / не замужем                 4      M    сотрудник     0
# 37       гражданский брак                 1      F    компаньон     0
# 38  не женат / не замужем                 4      M    сотрудник     1
# 39       гражданский брак                 1      F    компаньон     0
# 40  не женат / не замужем                 4      M    компаньон     0
# 41        женат / замужем                 0      F  госслужащий     0
# 42  не женат / не замужем                 4      F    сотрудник     0
# 43              в разводе                 3      F    компаньон     0
# 44        женат / замужем                 0      F    сотрудник     0
# 45  не женат / не замужем                 4      F    сотрудник     0
# 46        женат / замужем                 0      F    компаньон     0
# 47       гражданский брак                 1      M  госслужащий     0
# 48        женат / замужем                 0      F    сотрудник     0
# 49        женат / замужем                 0      F    сотрудник     0
#
#     total_income                                 purpose purpose_category
# 0         253875                           покупка жилья            жилье
# 1         112080                 приобретение автомобиля       автомобиль
# 2         145885                           покупка жилья            жилье
# 3         267628              дополнительное образование      образование
# 4         158616                         сыграть свадьбу           свдьба
# 5         255763                           покупка жилья            жилье
# 6         240525                       операции с жильем            жилье
# 7         135823                             образование      образование
# 8          95856                   на проведение свадьбы           свдьба
# 9         144425                 покупка жилья для семьи            жилье
# 10        113943                    покупка недвижимости     неджижимость
# 11         77069       покупка коммерческой недвижимости     неджижимость
# 12        145017                         сыграть свадьбу           свдьба
# 13        130458                 приобретение автомобиля       автомобиль
# 14        165127              покупка жилой недвижимости            жилье
# 15        116820  строительство собственной недвижимости     неджижимость
# 16        289202                            недвижимость     неджижимость
# 17         90410              строительство недвижимости     неджижимость
# 18         56823      на покупку подержанного автомобиля       автомобиль
# 19        242831            на покупку своего автомобиля       автомобиль
# 20        209552                            недвижимость     неджижимость
# 21        131812                 приобретение автомобиля       автомобиль
# 22        149681      на покупку подержанного автомобиля       автомобиль
# 23        128265                         сыграть свадьбу           свдьба
# 24        290547   операции с коммерческой недвижимостью     неджижимость
# 25         55112                    покупка недвижимости     неджижимость
# 26        145017                             образование      образование
# 27        308848  строительство собственной недвижимости     неджижимость
# 28        187863  строительство собственной недвижимости     неджижимость
# 29        145017        строительство жилой недвижимости            жилье
# 30        171456   операции с коммерческой недвижимостью     неджижимость
# 31        275485                                   жилье            жилье
# 32        139057                   на проведение свадьбы           свдьба
# 33        157245                           покупка жилья            жилье
# 34        104660         операции со своей недвижимостью     неджижимость
# 35         77805                   на проведение свадьбы           свдьба
# 36        138830                              автомобили       автомобиль
# 37        154128                 приобретение автомобиля       автомобиль
# 38        192247                             образование      образование
# 39        754240                   заняться образованием      образование
# 40        142865                    покупка недвижимости     неджижимость
# 41        145017        сделка с подержанным автомобилем       автомобиль
# 42         82065                   получение образования      образование
# 43        272957                 приобретение автомобиля       автомобиль
# 44        100780            на покупку своего автомобиля       автомобиль
# 45        106385                   заняться образованием      образование
# 46        182682        сделка с подержанным автомобилем       автомобиль
# 47        356277                   на проведение свадьбы           свдьба
# 48        162065  строительство собственной недвижимости     неджижимость
# 49         44591                              автомобиль       автомобиль

# %% [markdown]
# **Вывод**

# %% [markdown]
# * Была произведена лемматизация для целей получения кредита
# * Выделены основные на мой взгляд категории для получения кредита
# * Создан новый столбец `purpose_category` с основными целями получения кредита

# %% [markdown]
# ### Категоризация данных

# %% [markdown]
# **Категоризируем семейное положение и доход**

# %%
df['family_status'].value_counts() # делаем подсчет уникальных значений столбца family_status
# Out:
# женат / замужем          12339
# гражданский брак          4151
# не женат / не замужем     2810
# в разводе                 1195
# вдовец / вдова             959
# Name: family_status, dtype: int64

# %% [markdown]
# **Создадим новую таблицу:**

# %%
category_family_status = df[['family_status_id', 'family_status']] #новая таблица с идентификатором и семейным положением заёмщиков
category_family_status = category_family_status.drop_duplicates().reset_index(drop=True) # удаляем дубликаты
category_family_status
# Out:
#    family_status_id          family_status
# 0                 0        женат / замужем
# 1                 1       гражданский брак
# 2                 2         вдовец / вдова
# 3                 3              в разводе
# 4                 4  не женат / не замужем

# %% [markdown]
# **Категория для дохода**

# %% [markdown]
# **Выведем минимальный, средний и максимальный месячный доход:**

# %%
display(df['total_income' ].min())
display(df['total_income'].median())
display(df['total_income'].max())
# Out:
# 20667
# 145017.0
# 2265604

# %% [markdown]
# **Напишем функцию для классифакации доходов:**

# %%
def profit(total_income):
    if total_income <= 50000:
        return 'низкий доход'
    if total_income <= 150000:
        return 'средний доход'
    return 'высокий доход'
df['income_category'] = df['total_income'].apply(profit)

# %%
display(df.head(10)) #проверяем датафрейм
# Out:
#    children  days_employed  dob_years education  education_id  \
# 0         1             23         42    высшее             0
# 1         1             11         36   среднее             1
# 2         0             15         33   среднее             1
# 3         3             11         32   среднее             1
# 4         0             38         53   среднее             1
# 5         0              2         27    высшее             0
# 6         0              7         43    высшее             0
# 7         0              0         50   среднее             1
# 8         2             18         35    высшее             0
# 9         0              5         41   среднее             1
#
#       family_status  family_status_id gender income_type  debt  total_income  \
# 0   женат / замужем                 0      F   сотрудник     0        253875
# 1   женат / замужем                 0      F   сотрудник     0        112080
# 2   женат / замужем                 0      M   сотрудник     0        145885
# 3   женат / замужем                 0      M   сотрудник     0        267628
# 4  гражданский брак                 1      F   пенсионер     0        158616
# 5  гражданский брак                 1      M   компаньон     0        255763
# 6   женат / замужем                 0      F   компаньон     0        240525
# 7   женат / замужем                 0      M   сотрудник     0        135823
# 8  гражданский брак                 1      F   сотрудник     0         95856
# 9   женат / замужем                 0      M   сотрудник     0        144425
#
#                       purpose purpose_category income_category
# 0               покупка жилья            жилье   высокий доход
# 1     приобретение автомобиля       автомобиль   средний доход
# 2               покупка жилья            жилье   средний доход
# 3  дополнительное образование      образование   высокий доход
# 4             сыграть свадьбу           свдьба   высокий доход
# 5               покупка жилья            жилье   высокий доход
# 6           операции с жильем            жилье   высокий доход
# 7                 образование      образование   средний доход
# 8       на проведение свадьбы           свдьба   средний доход
# 9     покупка жилья для семьи            жилье   средний доход

# %% [markdown]
# **Вывод**

# %% [markdown]
# **Были прокатегоризированы:**
# * Семейный статус и его его id
# * Доходы(Создан новый столбец `income_category` с классификацией уровней доходов)

# %% [markdown]
# ## Шаг 3. Ответим на вопросы

# %% [markdown]
# - Есть ли зависимость между наличием детей и возвратом кредита в срок?

# %%
df.groupby('children')['debt'].sum()
# Out:
# children
# 0    1063
# 1     445
# 2     202
# 3      27
# 4       4
# 5       0
# Name: debt, dtype: int64

# %% [markdown]
# **Вывод**

# %% [markdown]
# * **Судя по групирровке данных по количеству детей и задолженности, чем больше детей в семье, тем меньше задолженность по кредиту.**

# %%
relationship_of_children = df.groupby('children').agg({'debt':['mean','count']})
# мультииндекс переменуем так:
relationship_of_children = relationship_of_children.rename(columns={'debt':'Зависимость'}, level = 0)
relationship_of_children = relationship_of_children.rename(columns={'mean':'% Невозврата', 'count':'Кол-во заёмщиков'}, level = 1)
# индекс переменуем вот так:
relationship_of_children.index = relationship_of_children.index.rename('Кол-во детей')
#сменим формат числа через style.format
relationship_of_children.style.format({('Зависимость', '% Невозврата'):'{:.2%}', ('Зависимость', 'Кол-во заёмщиков'):'{:.2f}',})
# Out:
# <style  type="text/css" >
# </style><table id="T_beadc_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" colspan="2">Зависимость</th>    </tr>    <tr>        <th class="blank level1" ></th>        <th class="col_heading level1 col0" >% Невозврата</th>        <th class="col_heading level1 col1" >Кол-во заёмщиков</th>    </tr>    <tr>        <th class="index_name level0" >Кол-во детей</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_beadc_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_beadc_row0_col0" class="data row0 col0" >7.54%</td>
#                         <td id="T_beadc_row0_col1" class="data row0 col1" >14091.00</td>
#             </tr>
#             <tr>
#                         <th id="T_beadc_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_beadc_row1_col0" class="data row1 col0" >9.17%</td>
#                         <td id="T_beadc_row1_col1" class="data row1 col1" >4855.00</td>
#             </tr>
#             <tr>
#                         <th id="T_beadc_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_beadc_row2_col0" class="data row2 col0" >9.49%</td>
#                         <td id="T_beadc_row2_col1" class="data row2 col1" >2128.00</td>
#             </tr>
#             <tr>
#                         <th id="T_beadc_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_beadc_row3_col0" class="data row3 col0" >8.18%</td>
#                         <td id="T_beadc_row3_col1" class="data row3 col1" >330.00</td>
#             </tr>
#             <tr>
#                         <th id="T_beadc_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_beadc_row4_col0" class="data row4 col0" >9.76%</td>
#                         <td id="T_beadc_row4_col1" class="data row4 col1" >41.00</td>
#             </tr>
#             <tr>
#                         <th id="T_beadc_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_beadc_row5_col0" class="data row5 col0" >0.00%</td>
#                         <td id="T_beadc_row5_col1" class="data row5 col1" >9.00</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# - Есть ли зависимость между семейным положением и возвратом кредита в срок?

# %%
df.groupby('family_status')['debt'].sum()
# Out:
# family_status
# в разводе                 85
# вдовец / вдова            63
# гражданский брак         388
# женат / замужем          931
# не женат / не замужем    274
# Name: debt, dtype: int64

# %%
dependence_on_income = df.groupby(['family_status_id', 'family_status']).agg({'debt':['mean','count']})
dependence_on_income = dependence_on_income.rename(columns={'debt':'Зависимость'}, level = 0)
dependence_on_income = dependence_on_income.rename(columns={'mean':'% Невозврата', 'count':'Кол-во заёмщиков'}, level = 1)
dependence_on_income.index = dependence_on_income.index.rename(['id с/п', 'семейное положение'])
dependence_on_income.style.format({('Зависимость', '% Невозврата'):'{:.2%}', ('Зависимость', 'Кол-во заёмщиков'):'{:.2f}',})
# Out:
# <style  type="text/css" >
# </style><table id="T_d7d75_" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" colspan="2">Зависимость</th>    </tr>    <tr>        <th class="blank" ></th>        <th class="blank level1" ></th>        <th class="col_heading level1 col0" >% Невозврата</th>        <th class="col_heading level1 col1" >Кол-во заёмщиков</th>    </tr>    <tr>        <th class="index_name level0" >id с/п</th>        <th class="index_name level1" >семейное положение</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d7d75_level0_row0" class="row_heading level0 row0" >0</th>
#                         <th id="T_d7d75_level1_row0" class="row_heading level1 row0" >женат / замужем</th>
#                         <td id="T_d7d75_row0_col0" class="data row0 col0" >7.55%</td>
#                         <td id="T_d7d75_row0_col1" class="data row0 col1" >12339.00</td>
#             </tr>
#             <tr>
#                         <th id="T_d7d75_level0_row1" class="row_heading level0 row1" >1</th>
#                         <th id="T_d7d75_level1_row1" class="row_heading level1 row1" >гражданский брак</th>
#                         <td id="T_d7d75_row1_col0" class="data row1 col0" >9.35%</td>
#                         <td id="T_d7d75_row1_col1" class="data row1 col1" >4151.00</td>
#             </tr>
#             <tr>
#                         <th id="T_d7d75_level0_row2" class="row_heading level0 row2" >2</th>
#                         <th id="T_d7d75_level1_row2" class="row_heading level1 row2" >вдовец / вдова</th>
#                         <td id="T_d7d75_row2_col0" class="data row2 col0" >6.57%</td>
#                         <td id="T_d7d75_row2_col1" class="data row2 col1" >959.00</td>
#             </tr>
#             <tr>
#                         <th id="T_d7d75_level0_row3" class="row_heading level0 row3" >3</th>
#                         <th id="T_d7d75_level1_row3" class="row_heading level1 row3" >в разводе</th>
#                         <td id="T_d7d75_row3_col0" class="data row3 col0" >7.11%</td>
#                         <td id="T_d7d75_row3_col1" class="data row3 col1" >1195.00</td>
#             </tr>
#             <tr>
#                         <th id="T_d7d75_level0_row4" class="row_heading level0 row4" >4</th>
#                         <th id="T_d7d75_level1_row4" class="row_heading level1 row4" >не женат / не замужем</th>
#                         <td id="T_d7d75_row4_col0" class="data row4 col0" >9.75%</td>
#                         <td id="T_d7d75_row4_col1" class="data row4 col1" >2810.00</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# **Вывод**

# %% [markdown]
# * **Исходя из данных вдоцы(вдовы) возвращают кредит чаще всех прочих из этой категории. Те, кто состоит в браке реже всех возвращают кредит в срок.**

# %% [markdown]
# - Есть ли зависимость между уровнем дохода и возвратом кредита в срок?

# %%
df.groupby('income_category')['debt'].sum()
# Out:
# income_category
# высокий доход    726
# низкий доход      23
# средний доход    992
# Name: debt, dtype: int64

# %%
report = df.groupby('income_category').agg({'debt':['mean','count']})
report = report.rename(columns={'debt':'Зависимость'}, level = 0)
report = report.rename(columns={'mean':'% Невозврата', 'count':'Кол-во заёмщиков'}, level = 1)
report.index = report.index.rename('уровень дохода')
report.style.format({('Зависимость', '% Невозврата'):'{:.2%}', ('Зависимость', 'Кол-во заёмщиков'):'{:.2f}',})
# Out:
# <style  type="text/css" >
# </style><table id="T_c160a_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" colspan="2">Зависимость</th>    </tr>    <tr>        <th class="blank level1" ></th>        <th class="col_heading level1 col0" >% Невозврата</th>        <th class="col_heading level1 col1" >Кол-во заёмщиков</th>    </tr>    <tr>        <th class="index_name level0" >уровень дохода</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c160a_level0_row0" class="row_heading level0 row0" >высокий доход</th>
#                         <td id="T_c160a_row0_col0" class="data row0 col0" >7.91%</td>
#                         <td id="T_c160a_row0_col1" class="data row0 col1" >9184.00</td>
#             </tr>
#             <tr>
#                         <th id="T_c160a_level0_row1" class="row_heading level0 row1" >низкий доход</th>
#                         <td id="T_c160a_row1_col0" class="data row1 col0" >6.18%</td>
#                         <td id="T_c160a_row1_col1" class="data row1 col1" >372.00</td>
#             </tr>
#             <tr>
#                         <th id="T_c160a_level0_row2" class="row_heading level0 row2" >средний доход</th>
#                         <td id="T_c160a_row2_col0" class="data row2 col0" >8.34%</td>
#                         <td id="T_c160a_row2_col1" class="data row2 col1" >11898.00</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# **Вывод**

# %% [markdown]
# * **Исходя из данных заёмщики с низким доходом возвращают кредит чаще, чем заёмщики со средним и высоким доходом.**

# %% [markdown]
# - Как разные цели кредита влияют на его возврат в срок?

# %%
df.groupby('purpose_category')['debt'].sum()
# Out:
# purpose_category
# автомобиль      403
# жилье           397
# неджижимость    385
# образование     370
# свдьба          186
# Name: debt, dtype: int64

# %%
report = df.groupby('purpose_category').agg({'debt':['mean','count']})
report = report.rename(columns={'debt':'Зависимость'}, level = 0)
report = report.rename(columns={'mean':'% Невозврата', 'count':'Кол-во заёмщиков'}, level = 1)
report.index = report.index.rename('цели кредита')
report.style.format({('Зависимость', '% Невозврата'):'{:.2%}', ('Зависимость', 'Кол-во заёмщиков'):'{:.2f}',})
# Out:
# <style  type="text/css" >
# </style><table id="T_3b4d0_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" colspan="2">Зависимость</th>    </tr>    <tr>        <th class="blank level1" ></th>        <th class="col_heading level1 col0" >% Невозврата</th>        <th class="col_heading level1 col1" >Кол-во заёмщиков</th>    </tr>    <tr>        <th class="index_name level0" >цели кредита</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_3b4d0_level0_row0" class="row_heading level0 row0" >автомобиль</th>
#                         <td id="T_3b4d0_row0_col0" class="data row0 col0" >9.36%</td>
#                         <td id="T_3b4d0_row0_col1" class="data row0 col1" >4306.00</td>
#             </tr>
#             <tr>
#                         <th id="T_3b4d0_level0_row1" class="row_heading level0 row1" >жилье</th>
#                         <td id="T_3b4d0_row1_col0" class="data row1 col0" >6.98%</td>
#                         <td id="T_3b4d0_row1_col1" class="data row1 col1" >5690.00</td>
#             </tr>
#             <tr>
#                         <th id="T_3b4d0_level0_row2" class="row_heading level0 row2" >неджижимость</th>
#                         <td id="T_3b4d0_row2_col0" class="data row2 col0" >7.52%</td>
#                         <td id="T_3b4d0_row2_col1" class="data row2 col1" >5121.00</td>
#             </tr>
#             <tr>
#                         <th id="T_3b4d0_level0_row3" class="row_heading level0 row3" >образование</th>
#                         <td id="T_3b4d0_row3_col0" class="data row3 col0" >9.22%</td>
#                         <td id="T_3b4d0_row3_col1" class="data row3 col1" >4013.00</td>
#             </tr>
#             <tr>
#                         <th id="T_3b4d0_level0_row4" class="row_heading level0 row4" >свдьба</th>
#                         <td id="T_3b4d0_row4_col0" class="data row4 col0" >8.00%</td>
#                         <td id="T_3b4d0_row4_col1" class="data row4 col1" >2324.00</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# **Вывод**

# %% [markdown]
# * **Наиболее надёжными категориями для банка являются: жилье и недвижимость. Самая большая просрочка в категориях: автомобиль, образование.**

# %% [markdown]
# ## Шаг 4. Общий вывод

# %% [markdown]
# **Изходя из проанализированных данных мы обнаружили, что:**
# * Данные имеют 2174 пропуска
# * Есть некорректные значения в доходах и стаже работы заёмщиков
# * Есть повторящиющиеся значения(дубликаты)
# * Мы привели к словарным значениям некорректно записанные категории
# * Категоризированы данные по классификациям дохода заёмщиков(низкий доход, средний доход, высокий доход)
#
# **На основании проанализированных данных мы делаем вывод:**
# * есть прямая зависимость между наличием детей и возвратом кредита в срок, а именно: многодетные семьи имеют меньше задолженность по кредиту
# * вдоцы(вдовы) возвращают кредит чаще всех прочих из этой категории. Те, кто состоит в браке реже всех возвращают кредит в срок
# * заёмщики с низким доходом возвращают кредит чаще, чем заёмщики со средним и высоким доходом
# * Наиболее надёжными категориями для банка являются: жилье и недвижимость. Самая большая просрочка в категориях: автомобиль, образование.
